# %% [markdown]
# # Lista 4
#
# ## Pandas: dane tabluarne
#
# (6pkt + 3pkt)
#
# Na liście znajdują się 2 zadania. Podczas ćwiczeń wykonaj jedno z nich. Po rozwiązaniu zadania pokaż kod prowadzącemu i odpowiedz na **pytanie kontrolne** — tylko wtedy przyznajemy punkty. Dodatkowo prześlij zadanie na platformie skos.
#
# Zadanie dodatkowe oznaczone jest ⭐️. Za wykonanie zadania otrzymasz 3pkt.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# drive_data_path = '/content/drive/MyDrive/UWr/WAI/Lista4/data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Titanic Dataset
#
# Przeanalizuj zbiór danych [**Titanic Dataset**](https://www.kaggle.com/datasets/yasserh/titanic-dataset?utm_source=chatgpt.com). Znajdź ciekawe informacje i zależności.
#
# > **Uwaga:** Nie musisz wykonywać poniższego polecenia, ale może ono pomóc oszacować nakład pracy potrzebny na zdobycie maksymalnej liczby punktów. Możesz samodzielnie zbadać ten zbiór danych.
#
# ### Zadania
#
# Wczytaj bazę danych i wykonaj poniższe polecenia:
#
# 1. Wyświetl początek danych (`head()`) oraz opis statystyczny (`describe()`).
# 2. Znajdź wszystkich pasażerów płci żeńskiej, którzy przeżyli (`Survived == 1`).
# 3. Oblicz średnią i medianę ceny biletu (`Fare`).
# 4. Policz, ilu mężczyzn i kobiet znajduje się w danych (`value_counts()` dla kolumny `Sex`).
# 5. Oblicz procent przeżycia kobiet i mężczyzn w tym zbiorze.
# 6. Dodaj kolumnę `IsChild` — oznacz pasażerów poniżej 18 roku życia. Następnie zobacz, ilu z nich przeżyło.
# 7. Sprawdź, ilu pasażerów klasy 1 i klasy 3 przeżyło, używając filtrowania (`Pclass`).
# 8. Znajdź wszystkich pasażerów, którzy:
#     - zapłacili więcej niż średnia cena biletu (`Fare > mean_fare`),
#     - byli kobietami,
#     - oraz przeżyli.
#
#     Posortuj wynik malejąco po `Fare`.
#
# > **Wskazówka:** Całość można wykonać w ok. 13 linijkach kodu Pandas.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./Titanic-Dataset.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[(df['Sex'] == 'female') & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]

# %%
print(df['Fare'].mean())
print(df['Fare'].median())
# Out:
# 32.204207968574636
# 14.4542

# %%
sex_counts = df['Sex'].value_counts()
print(sex_counts)
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
lived = df[df['Survived'] == 1]['Sex'].value_counts()
print(lived/sex_counts)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: count, dtype: float64

# %%
df['IsChild'] = df['Age'] < 18
print(df[df['IsChild'] == True].head())
print(df[df['IsChild'] == False].head())
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 7             8         0       3        Palsson, Master. Gosta Leonard
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16           17         0       3                  Rice, Master. Eugene
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked  IsChild
# 7     male   2.0      3      1   349909  21.0750   NaN        S     True
# 9   female  14.0      1      0   237736  30.0708   NaN        C     True
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S     True
# 14  female  14.0      0      0   350406   7.8542   NaN        S     True
# 16    male   2.0      4      1   382652  29.1250   NaN        Q     True
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  IsChild
# 0      0         A/5 21171   7.2500   NaN        S    False
# 1      0          PC 17599  71.2833   C85        C    False
# 2      0  STON/O2. 3101282   7.9250   NaN        S    False
# 3      0            113803  53.1000  C123        S    False
# 4      0            373450   8.0500   NaN        S    False

# %%
pclass_counts = df[df["Pclass"] != 2]['Pclass'].value_counts()
print(pclass_counts)

pclass_lived = df[(df["Pclass"] != 2) & (df['Survived'] == 1)]['Pclass'].value_counts()
print(pclass_lived)

pclass_lived_stats = pclass_lived/pclass_counts
print(pclass_lived_stats)
# Out:
# Pclass
# 3    491
# 1    216
# Name: count, dtype: int64
# Pclass
# 1    136
# 3    119
# Name: count, dtype: int64
# Pclass
# 1    0.629630
# 3    0.242363
# Name: count, dtype: float64

# %%
mean_fare = df["Fare"].mean()
print(mean_fare)

df_filtered = df[(df["Fare"] > mean_fare) & (df["Sex"] == "female") & (df["Survived"] == 1)]

df_filtered = df_filtered.sort_values(by="Fare", ascending=False)

df_filtered.head()
# Out:
# 32.204207968574636
#      PassengerId  Survived  Pclass                                   Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 311          312         1       1             Ryerson, Miss. Emily Borie
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292              NaN        C
# 88   female  23.0      3      2     19950  263.0000      C23 C25 C27        S
# 341  female  24.0      3      2     19950  263.0000      C23 C25 C27        S
# 742  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 311  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
#
#      IsChild
# 258    False
# 88     False
# 341    False
# 742    False
# 311    False

# %%
mean_fare ="aa"
df.query("Fare > @mean_fare and Sex == 'female' and Survived == 1").sort_values(by="Fare", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2779928965.py in <cell line: 0>()
#       1 mean_fare ="aa"
# ----> 2 df.query("Fare > @mean_fare and Sex == 'female' and Survived == 1").sort_values(by="Fare", ascending=False)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
# -> 4823         res = self.eval(expr, **kwargs)
#    4824
#    4825         try:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4947         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4948
# -> 4949         return _eval(expr, inplace=inplace, **kwargs)
#    4950
#    4951     def select_dtypes(self, include=None, exclude=None) -> Self:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     355         eng = ENGINES[engine]
#     356         eng_inst = eng(parsed_expr)
# --> 357         ret = eng_inst.evaluate()
#     358
#     359         if parsed_expr.assigner is None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/engines.py in evaluate(self)
#      79
#      80         # make sure no names in resolvers and locals/globals clash
# ---> 81         res = self._evaluate()
#      82         return reconstruct_object(
#      83             self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/engines.py in _evaluate(self)
#     119         scope = env.full_scope
#     120         _check_ne_builtin_clash(self.expr)
# --> 121         return ne.evaluate(s, local_dict=scope)
#     122
#     123
#
# /usr/local/lib/python3.12/dist-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, sanitize, _frame_depth, **kwargs)
#     989         return re_evaluate(local_dict=local_dict, global_dict=global_dict, _frame_depth=_frame_depth)
#     990     else:
# --> 991         raise e
#     992
#     993 def re_evaluate(local_dict: Optional[Dict] = None,
#
# /usr/local/lib/python3.12/dist-packages/numexpr/necompiler.py in validate(ex, local_dict, global_dict, out, order, casting, _frame_depth, sanitize, **kwargs)
#     897
#     898         # Create a signature
# --> 899         signature = [(name, getType(arg)) for (name, arg) in
#     900                     zip(names, arguments)]
#     901
#
# /usr/local/lib/python3.12/dist-packages/numexpr/necompiler.py in getType(a)
#     730         return bytes
#     731     if kind == 'U':
# --> 732         raise ValueError('NumExpr 2 does not support Unicode as a dtype.')
#     733     raise ValueError("unknown type %s" % a.dtype.name)
#     734
#
# ValueError: NumExpr 2 does not support Unicode as a dtype.

# %%
nan_cabin = df[df["Cabin"].isna()]
print(nan_cabin.describe())
print(nan_cabin.head())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   687.000000  687.000000  687.000000  529.000000  687.000000
# mean    443.208151    0.299854    2.639010   27.555293    0.547307
# std     259.215905    0.458528    0.589602   13.472634    1.207492
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     214.500000    0.000000    2.000000   19.000000    0.000000
# 50%     441.000000    0.000000    3.000000   26.000000    0.000000
# 75%     664.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   74.000000    8.000000
#
#             Parch        Fare
# count  687.000000  687.000000
# mean     0.365357   19.157325
# std      0.827106   28.663343
# min      0.000000    0.000000
# 25%      0.000000    7.877100
# 50%      0.000000   10.500000
# 75%      0.000000   23.000000
# max      6.000000  512.329200
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 7            8         0       3  Palsson, Master. Gosta Leonard    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  IsChild
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S    False
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    False
# 4  35.0      0      0            373450   8.0500   NaN        S    False
# 5   NaN      0      0            330877   8.4583   NaN        Q    False
# 7   2.0      3      1            349909  21.0750   NaN        S     True

# %%
cabin_by_class=nan_cabin[['Cabin', 'Pclass']]
print(cabin_by_class)
print(cabin_by_class.groupby('Pclass').size())
# Out:
#     Cabin  Pclass
# 0     NaN       3
# 2     NaN       3
# 4     NaN       3
# 5     NaN       3
# 7     NaN       3
# ..    ...     ...
# 884   NaN       3
# 885   NaN       3
# 886   NaN       2
# 888   NaN       3
# 890   NaN       3
#
# [687 rows x 2 columns]
# Pclass
# 1     40
# 2    168
# 3    479
# dtype: int64

# %% [markdown]
# ## Sleep Health and Lifestyle Dataset
#
# Przeanalizuj zbiór danych [**Sleep Health and Lifestyle Dataset**](https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset). Znajdź ciekawe informacje i zależności.
#
# > **Uwaga:** Nie musisz wykonywać poniższego polecenia, ale może ono pomóc oszacować nakład pracy potrzebny na zdobycie maksymalnej liczby punktów. Możesz samodzielnie zbadać ten zbiór danych.
#
# ### Zadania
#
# Wczytaj bazę danych i wykonaj poniższe polecenia:
#
# 1. Wyświetl początek danych (`head()`) oraz opis statystyczny (`describe()`).
# 2. Oblicz średni czas snu i średni poziom stresu w całej grupie.
# 3. Sprawdź, czy dłuższy sen wiąże się z lepszą jakością snu, używając korelacji (`corr()`).
#    > Jeśli korelacja bliska 1 – oznacza silną zależność (więcej snu = lepsza jakość).
# 4. Znajdź osoby, które:
#    - mają `Quality of Sleep >= 8`
#    - i `Stress Level <= 5`
# 5. Stwórz kolumnę `Lifestyle Score`, która będzie prostą miarą jakości stylu życia:
#    Lifestyle Score = (Quality of Sleep) + (Physical Activity Level / 10) - (Stress Level / 2)
# 6. Sprawdź, czy osoby z kategorią BMI „Overweight” mają niższą jakość snu niż osoby z „Normal”.
# 7. Sprawdź, czy osoby z wysokim poziomem stresu (`Stress Level > 7`) śpią krócej niż 6 godzin.
# 8. Stwórz kolumny z ciśnienia krwi:
#
#    ```python
#    df[['Systolic', 'Diastolic']] = df['Blood Pressure'].str.split('/', expand=True).astype(int)
#    ```
#
#    Następnie znajdź wszystkich, którzy:
#
#    * mają `Systolic > 125`,
#    * `BMI Category == "Overweight"`,
#    * `Sleep Duration < 6.5`,
#
#    i posortuj ich malejąco po `Stress Level`.
#
# > **Wskazówka:** Całość można wykonać w ok. 12 linijkach kodu Pandas.

# %% [markdown]
# # ⭐️ Most Streamed Spotify Songs 2023
#
# Odpowiedz na poniższe pytania dotyczące zbioru danych.
# Możesz wymienić dowolnych 7 zadań na własne — pamiętaj jednak, by nie były zbyt proste!

# %%
from google.colab import drive
drive.mount('/content/drive')
drive_data_path = '/content/drive/MyDrive/UWr/WAI/Lista4/data'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv(drive_data_path + '/spotify-2023.csv', encoding='latin1')

df.columns = df.columns.str.strip()

numeric_cols = [
    'artist_count',
    'released_year', 'released_month', 'released_day',
    'in_spotify_playlists', 'in_spotify_charts', 'streams',
    'in_apple_playlists', 'in_apple_charts',
    'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts',
    'bpm',
    'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
    'instrumentalness_%', 'liveness_%', 'speechiness_%'
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

int_cols = [
    'artist_count', 'released_year', 'released_month', 'released_day',
    'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists',
    'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts',
    'in_shazam_charts', 'bpm'
]

for col in int_cols:
    if df[col].notna().all():
        df[col] = df[col].astype(int)

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               952 non-null    float64
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   874 non-null    float64
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      896 non-null    float64
#  14  bpm                   953 non-null    int64
#  15  key                   858 non-null    object
#  16  mode                  953 non-null    object
#  17  danceability_%        953 non-null    int64
#  18  valence_%             953 non-null    int64
#  19  energy_%              953 non-null    int64
#  20  acousticness_%        953 non-null    int64
#  21  instrumentalness_%    953 non-null    int64
#  22  liveness_%            953 non-null    int64
#  23  speechiness_%         953 non-null    int64
# dtypes: float64(3), int64(17), object(4)
# memory usage: 178.8+ KB
# None

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm  key   mode  \
# 0                147  141381703.0                  43  ...  125    B  Major
# 1                 48  133716286.0                  48  ...   92   C#  Major
# 2                113  140003974.0                  94  ...  138    F  Major
# 3                100  800840817.0                 116  ...  170    A  Major
# 4                 50  303236322.0                  84  ...  144    A  Minor
#
#    danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0              80         89       83             31                   0
# 1              71         61       74              7                   0
# 2              51         32       53             17                   0
# 3              55         58       72             11                   0
# 4              65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Zadanie 1.
#
# **Które utwory są najczęściej dodawane do playlist (suma ze wszystkich platform)?**
#
# **Rozwiązanie:**

# %%
df['in_playlist'] = df['in_spotify_playlists'] + df['in_apple_playlists'] + df['in_deezer_playlists']
ordered = df.sort_values(by='in_playlist', ascending=False)
ordered.head()
# Out:
#                                         track_name            artist(s)_name  \
# 657                                           Lost               Frank Ocean
# 110                                    Money Trees  Kendrick Lamar, Jay Rock
# 41   Sunflower - Spider-Man: Into the Spider-Verse     Post Malone, Swae Lee
# 14                                       As It Was              Harry Styles
# 71                                      Heat Waves             Glass Animals
#
#      artist_count  released_year  released_month  released_day  \
# 657             1           2012               1             1
# 110             2           2012               1             1
# 41              2           2018              10             9
# 14              1           2022               3            31
# 71              1           2020               6            28
#
#      in_spotify_playlists  in_spotify_charts       streams  \
# 657                 29499                 11  8.222397e+08
# 110                 26792                 32  1.093606e+09
# 41                  24094                 78  2.808097e+09
# 14                  23575                130  2.513188e+09
# 71                  22543                 63  2.557976e+09
#
#      in_apple_playlists  ...  key   mode  danceability_%  valence_%  energy_%  \
# 657                 124  ...   A#  Minor              91         49        61
# 110                  69  ...    E  Minor              74         37        53
# 41                  372  ...    D  Major              76         91        50
# 14                  403  ...   F#  Minor              52         66        73
# 71                  386  ...    B  Major              76         53        53
#
#     acousticness_% instrumentalness_%  liveness_%  speechiness_%  in_playlist
# 657              3                  0          17             22      30210.0
# 110              7                  0          21             10      27556.0
# 41              54                  0           7              5      25309.0
# 14              34                  0          31              6      24841.0
# 71              44                  0           9              9      23636.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Zadanie 2.
#
# **Czy bardziej taneczne utwory (`danceability_%`) mają wyższą energię (`energy_%`)?** Sprawdź współczynnik korelacji.
#
# **Rozwiązanie:**

# %%
df2 = df[['danceability_%', 'energy_%']]
df2.corr()
# Out:
#                 danceability_%  energy_%
# danceability_%        1.000000  0.198095
# energy_%              0.198095  1.000000

# %% [markdown]
# nie - korelacja między danceability a energy jest niska

# %% [markdown]
# ## Zadanie 3.
#
# **Które utwory są "taneczne i smutne"?** Czyli `danceability_% > 75` i `valence_% < 50`. Użyj `query()`.
#
# **Rozwiązanie:**

# %%
df.query("`danceability_%` > 75 and `valence_%` < 50")
# Out:
#              track_name               artist(s)_name  artist_count  \
# 8              fukumean                        Gunna             1
# 58                  S91                      Karol G             1
# 64              Hey Mor                  Ozuna, Feid             2
# 87      Me Porto Bonito  Chencho Corleone, Bad Bunny             2
# 88               Makeba                         Jain             1
# ..                  ...                          ...           ...
# 931  Major Distribution             Drake, 21 Savage             2
# 933      Vigilante Shit                 Taylor Swift             1
# 935               On BS             Drake, 21 Savage             2
# 939         Spin Bout U             Drake, 21 Savage             2
# 945     BackOutsideBoyz                        Drake             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 8             2023               5            15                  1096
# 58            2023               7            14                   525
# 64            2022              10             6                  4637
# 87            2022               5             6                  8870
# 88            2015               6            22                  6060
# ..             ...             ...           ...                   ...
# 931           2022              11             4                  1545
# 933           2022              10            21                  1948
# 935           2022              11             4                  1338
# 939           2022              11             4                  1652
# 945           2022              11             4                  1045
#
#      in_spotify_charts       streams  in_apple_playlists  ...  key   mode  \
# 8                   83  9.521732e+07                  60  ...   C#  Minor
# 58                  41  1.601133e+07                  34  ...  NaN  Minor
# 64                  38  6.740727e+08                  63  ...   C#  Minor
# 87                  43  1.440758e+09                 104  ...   C#  Minor
# 88                  53  1.654841e+08                 150  ...    D  Major
# ..                 ...           ...                 ...  ...  ...    ...
# 931                  0  1.548632e+08                  22  ...   G#  Minor
# 933                  0  2.536508e+08                  12  ...    E  Minor
# 935                  0  1.704139e+08                   9  ...    A  Major
# 939                  2  1.983655e+08                  26  ...    G  Major
# 945                  0  9.336754e+07                   8  ...    F  Minor
#
#      danceability_%  valence_%  energy_% acousticness_% instrumentalness_%  \
# 8                85         22        62             12                  0
# 58               86         42        72             59                  0
# 64               90         40        59              0                  0
# 87               91         43        71              9                  0
# 88               82         40        66             39                 51
# ..              ...        ...       ...            ...                ...
# 931              91         23        55              1                  0
# 933              80         16        28             17                  0
# 935              84         33        36              2                  0
# 939              77         20        70              1                  0
# 945              85         40        43              4                  0
#
#      liveness_%  speechiness_%  in_playlist
# 8            28              9       1204.0
# 58            9             19        598.0
# 64           10             29       4789.0
# 87            9              8       9115.0
# 88           25              7          NaN
# ..          ...            ...          ...
# 931           7             32       1582.0
# 933          12             39       1976.0
# 935          39             59       1354.0
# 939          16              5       1688.0
# 945          39             32       1055.0
#
# [83 rows x 25 columns]

# %% [markdown]
# ## Zadanie 4.
#
# **Jakie jest średnie tempo (`bpm`) wszystkich utworów wydanych po 2020 roku?**

# %%
df.query("released_year > 2020")['bpm'].mean()
# Out:
# np.float64(123.17672413793103)

# %% [markdown]
# ## Zadanie 5.
#
# **Znajdź najżywszy (`liveness_%`) i najbardziej instrumentalny (`instrumentalness_%`) utwór.** Skorzystaj z `idxmax()`.
#
# **Rozwiązanie:**

# %%
idx_max_liveness = df['liveness_%'].idxmax()
idx_max_instrumentalness = df['instrumentalness_%'].idxmax()

print("Max liveness:")
print(df.loc[idx_max_liveness])
print("Max instrumentalness")
print(df.loc[idx_max_instrumentalness])
# Out:
# Max liveness:
# track_name                                       Vai Lï¿½ï¿½ Em Casa
# artist(s)_name          Marï¿½ï¿½lia Mendonï¿½ï¿½a, George Henrique &
# artist_count                                                        2
# released_year                                                    2021
# released_month                                                     10
# released_day                                                       22
# in_spotify_playlists                                              772
# in_spotify_charts                                                   0
# streams                                                   263894529.0
# in_apple_playlists                                                  7
# in_apple_charts                                                     3
# in_deezer_playlists                                              89.0
# in_deezer_charts                                                    0
# in_shazam_charts                                                  0.0
# bpm                                                               158
# key                                                                G#
# mode                                                            Minor
# danceability_%                                                     46
# valence_%                                                          62
# energy_%                                                           83
# acousticness_%                                                     53
# instrumentalness_%                                                  0
# liveness_%                                                         97
# speechiness_%                                                      28
# in_playlist                                                     868.0
# Name: 601, dtype: object
# Max instrumentalness
# track_name              Alien Blues
# artist(s)_name             Vundabar
# artist_count                      1
# released_year                  2015
# released_month                    7
# released_day                     24
# in_spotify_playlists           1930
# in_spotify_charts                 0
# streams                 370068639.0
# in_apple_playlists                3
# in_apple_charts                   0
# in_deezer_playlists            28.0
# in_deezer_charts                  0
# in_shazam_charts                1.0
# bpm                              82
# key                              D#
# mode                          Major
# danceability_%                   47
# valence_%                        44
# energy_%                         76
# acousticness_%                    8
# instrumentalness_%               91
# liveness_%                        9
# speechiness_%                     3
# in_playlist                  1961.0
# Name: 684, dtype: object

# %% [markdown]
# ## Zadanie 6.
#
# **Oblicz średnią energię dla utworów z BPM pomiędzy 90 a 130.** Użyj `between()` i `.mean()`.
#
# **Rozwiązanie:**

# %%
df[df['bpm'].between(90, 130)]['energy_%'].mean()
# Out:
# np.float64(66.49806201550388)

# %% [markdown]
# ## Zadanie 7.
#
# **Sprawdź, czy utwory z tonacją Major mają wyższy średni `valence_%` (czyli bardziej „pozytywne emocje”) niż Minor.**
#
# **Rozwiązanie:**

# %%
for mode in df['mode'].unique():
    print(mode, df[df['mode'] == mode]['valence_%'].mean())
# Out:
# Major 50.13818181818182
# Minor 53.19602977667494

# %% [markdown]
# ## Zadanie 8.
#
# **Który utwór ma najwyższy stosunek energii do akustyczności?** Oblicz nową kolumnę `energy_to_acoustic` i znajdź maksimum.
#
# **Rozwiązanie:**

# %%
df['energy_to_acoustic'] = df['energy_%'] / df['acousticness_%']
df.loc[df['energy_to_acoustic'].idxmax()]
# Out:
# track_name               Like Crazy
# artist(s)_name                Jimin
# artist_count                      1
# released_year                  2023
# released_month                    3
# released_day                     24
# in_spotify_playlists            596
# in_spotify_charts                68
# streams                 363369738.0
# in_apple_playlists                8
# in_apple_charts                 104
# in_deezer_playlists            23.0
# in_deezer_charts                  2
# in_shazam_charts               29.0
# bpm                             120
# key                               G
# mode                          Major
# danceability_%                   63
# valence_%                        36
# energy_%                         73
# acousticness_%                    0
# instrumentalness_%                0
# liveness_%                       36
# speechiness_%                     4
# in_playlist                   627.0
# energy_to_acoustic              inf
# Name: 19, dtype: object

# %% [markdown]
# ## Zadanie 9.
#
# **Które utwory mają ekstremalne (nietypowe) tempo — poniżej 70 lub powyżej 160 BPM — ale mimo to mają wysoką taneczność (`danceability_% > 70`)?**
#
# **Rozwiązanie:**

# %%
df[~df['bpm'].between(70, 160)].query("`danceability_%` > 70")
# Out:
#                               track_name  \
# 9                        La Bebe - Remix
# 34                                   TQG
# 78                            Yandel 150
# 91             What It Is (Solo Version)
# 227                               Normal
# 261                        X SI VOLVEMOS
# 306                              La Bebe
# 356                                WANDA
# 368                          LA CANCIï¿½
# 456                        Love Language
# 547                               Volvï¿
# 594                               Sobrio
# 607                                 2055
# 632                             AM Remix
# 674                           Contection
# 708                               Jordan
# 794                           Mr. Morale
# 837  La Llevo Al Cielo (Ft. ï¿½ï¿½engo F
# 846                         Keep Driving
# 885         Si Te La Encuentras Por Ahï¿
# 928                    California Breeze
#
#                                         artist(s)_name  artist_count  \
# 9                                Peso Pluma, Yng Lvcas             2
# 34                                    Karol G, Shakira             2
# 78                                        Yandel, Feid             2
# 91                                             Doechii             1
# 227                                               Feid             1
# 261                              Karol G, Romeo Santos             2
# 306                                          Yng Lvcas             1
# 356                                            Quevedo             1
# 368                                J Balvin, Bad Bunny             2
# 456                                                SZA             1
# 547                                Aventura, Bad Bunny             2
# 594                                             Maluma             1
# 607                                      Sleepy hallow             1
# 632                    J Balvin, Nio Garcia, Bad Bunny             3
# 674                                  GODZZ__-, Zakaria             2
# 708                                        Ryan Castro             1
# 794                        Kendrick Lamar, Tanna Leone             2
# 837  Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corl...             4
# 846                                       Harry Styles             1
# 885                                               Feid             1
# 928                                           Lil Baby             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 9             2023               3            17                  2953
# 34            2023               2            23                  4284
# 78            2022              12            20                  3618
# 91            2023               3            17                   804
# 227           2022               7             8                  2461
# 261           2023               2             2                  2127
# 306           2021              12            24                   489
# 356           2023               1            20                   888
# 368           2019               6            28                  6398
# 456           2022              12             9                  1127
# 547           2021               8             3                  5375
# 594           2021               7             8                  3506
# 607           2021               4            14                  2226
# 632           2021               6            24                  6556
# 674           2020               1            16                  6955
# 708           2021               4            30                  2844
# 794           2022               5            13                  1860
# 837           2022               5            20                  3559
# 846           2022               5            20                  2094
# 885           2022               8             5                  1379
# 928           2022              10            14                   991
#
#      in_spotify_charts       streams  in_apple_playlists  ...   mode  \
# 9                   44  5.536341e+08                  49  ...  Minor
# 34                  49  6.189904e+08                 115  ...  Minor
# 78                  38  5.856954e+08                  47  ...  Minor
# 91                  25  9.513200e+07                  29  ...  Minor
# 227                 36  4.592764e+08                  47  ...  Minor
# 261                 33  2.666245e+08                  45  ...  Minor
# 306                 17  1.919456e+08                   4  ...  Minor
# 356                 22  1.753993e+08                  11  ...  Minor
# 368                 31  1.435128e+09                 177  ...  Major
# 456                  0  1.108491e+08                  16  ...  Minor
# 547                 10  6.738011e+08                 138  ...  Major
# 594                 10  5.136439e+08                 103  ...  Major
# 607                  0  6.245155e+08                  29  ...  Minor
# 632                  0  5.285447e+08                  93  ...  Minor
# 674                  0  1.180896e+09                  65  ...  Minor
# 708                  2  3.940303e+08                  29  ...  Minor
# 794                  0  5.868742e+07                   1  ...  Major
# 837                  3  3.331465e+08                  36  ...  Minor
# 846                  1  2.360607e+08                   8  ...  Major
# 885                  4  1.790614e+08                  23  ...  Minor
# 928                  0  8.555936e+07                  36  ...  Minor
#
#      danceability_%  valence_%  energy_%  acousticness_% instrumentalness_%  \
# 9                81         56        48              21                  0
# 34               72         61        63              67                  0
# 78               78         58        73               5                  0
# 91               74         76        76               6                  0
# 227              71         59        56               4                  0
# 261              79         58        78              34                  0
# 306              78         75        46              62                  0
# 356              72         96        63              25                  0
# 368              75         43        65              15                  0
# 456              71         55        26              85                  0
# 547              73         79        86              42                  0
# 594              76         63        77              14                  0
# 607              78         65        52              46                  0
# 632              74         79        66              11                  0
# 674              81         83        75              14                  0
# 708              80         71        68               6                  0
# 794              73         26        54              30                  0
# 837              80         77        85              11                  0
# 846              72         90        48              32                  0
# 885              74         46        58              15                  0
# 928              74         22        67               0                  0
#
#     liveness_%  speechiness_%  in_playlist  energy_to_acoustic
# 9            8             33       3068.0            2.285714
# 34           9             28       4583.0            0.940299
# 78          10              7       3745.0           14.600000
# 91          10              9        857.0           12.666667
# 227         27             12       2553.0           14.000000
# 261         11             25       2225.0            2.294118
# 306         12             35        498.0            0.741935
# 356         21              7        906.0            2.520000
# 368         11             32       6880.0            4.333333
# 456         13              8       1151.0            0.305882
# 547          7             18       5646.0            2.047619
# 594         15             22       3709.0            5.500000
# 607         12             31       2299.0            1.130435
# 632          8             16       6716.0            6.000000
# 674         29             34       7418.0            5.357143
# 708         10             37       2908.0           11.333333
# 794         34             32       1864.0            1.800000
# 837         17             14       3626.0            7.727273
# 846         18             23       2120.0            1.500000
# 885         13              8       1420.0            3.866667
# 928         11             46       1040.0                 inf
#
# [21 rows x 26 columns]

# %% [markdown]
# ## Zadanie 10.
#
# **Policz, ile utworów przekracza 100 mln odtworzeń (`streams > 100_000_000`). Jaki procent wszystkich to stanowi?**
#
# **Rozwiązanie:**

# %%
over_100 = df.query('streams > 100_000_000')
print(over_100.shape[0])
print(over_100.shape[0] / df.shape[0])
# Out:
# 800
# 0.8394543546694648

# %% [markdown]
# ## Zadanie 11.
#
# **Znajdź utwory, które mają wysoką energię (`energy_% > 85`) i jednocześnie są bardzo często wyszukiwane na Shazam (`in_shazam_charts > 500`).
# Posortuj malejąco po liczbie wyszukiwań.**
#
# **Rozwiązanie:**

# %%
df.query('`energy_%` > 85 and in_shazam_charts > 500').sort_values(by='streams', ascending=False)
# Out:
#                         track_name                       artist(s)_name  \
# 152                   Danza Kuduro                    Don Omar, Lucenzo
# 42                 I'm Good (Blue)             Bebe Rexha, David Guetta
# 653               The Next Episode                  Dr. Dre, Snoop Dogg
# 121  Miracle (with Ellie Goulding)        Calvin Harris, Ellie Goulding
# 51              Baby Don't Hurt Me  David Guetta, Anne-Marie, Coi Leray
#
#      artist_count  released_year  released_month  released_day  \
# 152             2           2010               1             1
# 42              2           2022               8            26
# 653             2           1999               1             1
# 121             2           2023               3            10
# 51              3           2023               4             6
#
#      in_spotify_playlists  in_spotify_charts       streams  \
# 152                 17138                 37  1.279435e+09
# 42                  12482                 80  1.109433e+09
# 653                 31762                  0  8.433090e+08
# 121                  5120                 48  2.110508e+08
# 51                   4277                 66  1.777407e+08
#
#      in_apple_playlists  ...   mode  danceability_%  valence_%  energy_%  \
# 152                 119  ...  Major              47         86        92
# 42                  291  ...  Minor              56         38        97
# 653                 142  ...  Minor              92         31        89
# 121                 161  ...  Major              64         31        87
# 51                  145  ...  Major              60         23        91
#
#      acousticness_% instrumentalness_% liveness_%  speechiness_%  in_playlist  \
# 152               8                  0          5             24      18231.0
# 42                4                  0         35              4      13310.0
# 653               3                  0          8             25          NaN
# 121               4                  4          8              4       5527.0
# 51                0                  0         12              3       4635.0
#
#      energy_to_acoustic
# 152           11.500000
# 42            24.250000
# 653           29.666667
# 121           21.750000
# 51                  inf
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Zadanie 12.
#
# **Policz łączną liczbę playlist (Spotify + Apple + Deezer), w których występują wszystkie utwory razem.**
#
# **Rozwiązanie:**

# %%
total_playlists = df['in_spotify_playlists'].sum() + df['in_apple_playlists'].sum() + df['in_deezer_playlists'].sum()
print(total_playlists)
# Out:
# 5116257.0

# %% [markdown]
# ## Zadanie 13.
#
# **Czy utwory z wyższym `speechiness_%` mają niższą `valence_%` (czyli są bardziej „poważne”)?** Sprawdź korelację.
#
# **Rozwiązanie:**

# %%
df[['speechiness_%', 'valence_%']].corr()
# Out:
#                speechiness_%  valence_%
# speechiness_%       1.000000   0.041081
# valence_%           0.041081   1.000000

# %% [markdown]
# tak - są odwrotnie skorelowane

# %% [markdown]
# ## Zadanie 14.
#
# **Który utwór ma największą wartość `streams` w stosunku do liczby playlist (`streams / playlist_sum`)?**
#
# **Rozwiązanie:**

# %%
df['playlist_sum'] = df['in_spotify_playlists'] + df['in_apple_playlists'] + df['in_deezer_playlists']
df['stream_to_playlist_sum'] = df['streams'] / df['playlist_sum']
df.loc[df['stream_to_playlist_sum'].idxmax()]
# Out:
# track_name                      Dream On
# artist(s)_name                 Aerosmith
# artist_count                           1
# released_year                       1973
# released_month                         1
# released_day                           5
# in_spotify_playlists                 168
# in_spotify_charts                      0
# streams                      838586769.0
# in_apple_playlists                     0
# in_apple_charts                        0
# in_deezer_playlists                  5.0
# in_deezer_charts                       0
# in_shazam_charts                     0.0
# bpm                                   80
# key                                    F
# mode                               Minor
# danceability_%                        39
# valence_%                             24
# energy_%                              43
# acousticness_%                        39
# instrumentalness_%                     0
# liveness_%                            23
# speechiness_%                          3
# in_playlist                        173.0
# energy_to_acoustic              1.102564
# playlist_sum                       173.0
# stream_to_playlist_sum    4847322.364162
# Name: 425, dtype: object

# %% [markdown]
# ## Zadanie 15.
#
# **Znajdź wszystkie utwory wydane w lipcu (`released_month == 7`), które mają BPM powyżej średniego tempa w całej bazie.**
#
# **Rozwiązanie:**

# %%
avg_bpm = df['bpm'].mean()
df.query("`released_month` == 7 and `bpm` > @avg_bpm")
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 11                                           Super Shy
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 30                                                Rush
# 58                                                 S91
# 59                                            cardigan
# 68                                           Overdrive
# 74               Quevedo: Bzrp Music Sessions, Vol. 52
# 76                                        Here With Me
# 83                 Back To December (Taylor's Version)
# 84                           STAY (with Justin Bieber)
# 104                                          New Jeans
# 122                                           Nonsense
# 139                                  Romantic Homicide
# 193             Better Than Revenge (Taylor's Version)
# 227                                             Normal
# 278                                          DESPECHï¿
# 360                                          Lovezinho
# 399                                                 TV
# 410                  INDUSTRY BABY (feat. Jack Harlow)
# 418                                               Doja
# 570                                    Volando - Remix
# 594                                             Sobrio
# 637                                Permission to Dance
# 875                     Hot Shit (feat. Ye & Lil Durk)
# 891              Come Back Home - From "Purple Hearts"
# 894  Stay With Me (with Justin Timberlake, Halsey, ...
# 924                            2 Be Loved (Am I Ready)
# 930                                Casei Com a Putaria
#
#                                         artist(s)_name  artist_count  \
# 0                                     Latto, Jung Kook             2
# 11                                            NewJeans             1
# 21                                        Taylor Swift             1
# 30                                         Troye Sivan             1
# 58                                             Karol G             1
# 59                                        Taylor Swift             1
# 68                                         Post Malone             1
# 74                                   Bizarrap, Quevedo             2
# 76                                                d4vd             1
# 83                                        Taylor Swift             1
# 84                        Justin Bieber, The Kid Laroi             2
# 104                                           NewJeans             1
# 122                                  Sabrina Carpenter             1
# 139                                               d4vd             1
# 193                                       Taylor Swift             1
# 227                                               Feid             1
# 278                                           ROSALï¿½             1
# 360                                             Treyce             1
# 399                                      Billie Eilish             1
# 410                             Jack Harlow, Lil Nas X             2
# 418                                        Central Cee             1
# 570                              Sech, Bad Bunny, Mora             3
# 594                                             Maluma             1
# 637                                                BTS             1
# 875                      Kanye West, Lil Durk, Cardi B             3
# 891                                       Sofia Carson             1
# 894  Calvin Harris, Halsey, Pharrell Williams, Just...             4
# 924                                              Lizzo             1
# 930                 MC Ryan SP, Love Funk, Mc Paiva ZS             3
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 11            2023               7             7                   422
# 21            2023               7             7                   516
# 30            2023               7            13                   864
# 58            2023               7            14                   525
# 59            2020               7            24                  7923
# 68            2023               7            14                   410
# 74            2022               7             6                  8506
# 76            2022               7            17                  3246
# 83            2023               7             7                   139
# 84            2021               7             9                 17050
# 104           2023               7             7                    77
# 122           2022               7            15                  2346
# 139           2022               7            20                  2335
# 193           2023               7             7                    86
# 227           2022               7             8                  2461
# 278           2022               7            28                  7613
# 360           2022               7            28                   242
# 399           2022               7            21                  3009
# 410           2021               7            23                 13315
# 418           2022               7            20                  4169
# 570           2021               7             8                  3272
# 594           2021               7             8                  3506
# 637           2021               7             9                  1801
# 875           2022               7             1                  1601
# 891           2022               7            12                   367
# 894           2022               7            15                  3113
# 924           2022               7            14                  3682
# 930           2022               7             1                   648
#
#      in_spotify_charts       streams  in_apple_playlists  ...  valence_%  \
# 0                  147  1.413817e+08                  43  ...         89
# 11                  55  5.825515e+07                  37  ...         52
# 21                  38  5.213525e+07                  73  ...         82
# 30                  78  2.258116e+07                  71  ...         35
# 58                  41  1.601133e+07                  34  ...         42
# 59                  29  8.120196e+08                 106  ...         53
# 68                  36  1.478042e+07                  36  ...         48
# 74                  45  1.356565e+09                  94  ...         55
# 76                  23  6.354120e+08                  94  ...         27
# 83                  17  3.922893e+07                  16  ...         20
# 84                  36  2.665344e+09                 492  ...         48
# 104                 35  2.956222e+07                   8  ...         53
# 122                 27  3.428979e+08                  69  ...         68
# 139                 23  6.815831e+08                  82  ...         20
# 193                 11  3.034321e+07                   3  ...         67
# 227                 36  4.592764e+08                  47  ...         59
# 278                 33  7.823694e+08                 180  ...         78
# 360                  0  7.006974e+07                  12  ...         61
# 399                  2  3.385650e+08                  68  ...          9
# 410                  0  1.814350e+09                 300  ...         89
# 418                 44  4.822575e+08                  57  ...         97
# 570                 19  6.100456e+08                 101  ...         63
# 594                 10  5.136439e+08                 103  ...         63
# 637                  2  6.083340e+08                  77  ...         65
# 875                  0  8.592499e+07                  11  ...         52
# 891                  0  9.761045e+07                  28  ...         43
# 894                  0  1.234731e+08                  54  ...         90
# 924                  6  2.476891e+08                  41  ...         92
# 930                  4  1.877016e+08                   0  ...         62
#
#      energy_%  acousticness_%  instrumentalness_%  liveness_% speechiness_%  \
# 0          83              31                   0           8             4
# 11         82              18                   0          15             7
# 21         76               6                   0           6             3
# 30         84               0                   0          11             6
# 58         72              59                   0           9            19
# 59         58              55                   0          27             4
# 68         73               0                   0          35             4
# 74         78               1                   3          23             4
# 76         48              50                   0          12             3
# 83         64               1                   0          12             3
# 84         76               4                   0          10             5
# 104        72              51                   0          12             5
# 122        68               3                   0          26             4
# 139        55              45                   1          32             3
# 193        89               0                   0          19             8
# 227        56               4                   0          27            12
# 278        62              18                   0           6            10
# 360        59              30                   0          12             4
# 399        25              84                   1          14             4
# 410        70               2                   0           5             6
# 418        57              38                   0          40            29
# 570        69              21                   0          11             7
# 594        77              14                   0          15            22
# 637        74               1                   0          34             4
# 875        69               0                   0           8            23
# 891        53              24                   0          12             4
# 894        73              28                   0          29             4
# 924        77               9                   0           8            11
# 930        60              12                   0           5            44
#
#     in_playlist  energy_to_acoustic  playlist_sum  stream_to_playlist_sum
# 0         641.0            2.677419         641.0           220564.279251
# 11        480.0            4.555556         480.0           121364.895833
# 21        631.0           12.666667         631.0            82623.213946
# 30        985.0                 inf         985.0            22925.036548
# 58        598.0            1.220339         598.0            26774.792642
# 59       8171.0            1.054545        8171.0            99378.234855
# 68        477.0                 inf         477.0            30986.215933
# 74       8764.0           78.000000        8764.0           154788.349270
# 76       3408.0            0.960000        3408.0           186447.196303
# 83        160.0           64.000000         160.0           245180.806250
# 84      18340.0           19.000000       18340.0           145329.548637
# 104        89.0            1.411765          89.0           332159.775281
# 122      2453.0           22.666667        2453.0           139787.174073
# 139      2467.0            1.222222        2467.0           276280.148358
# 193        92.0                 inf          92.0           329817.456522
# 227      2553.0           14.000000        2553.0           179896.762632
# 278      8215.0            3.444444        8215.0            95236.686914
# 360       267.0            1.966667         267.0           262433.501873
# 399      3142.0            0.297619        3142.0           107754.608848
# 410     14305.0           35.000000       14305.0           126833.258511
# 418      4409.0            1.500000        4409.0           109380.234974
# 570      3443.0            3.285714        3443.0           177184.322103
# 594      3709.0            5.500000        3709.0           138485.824751
# 637      1952.0           74.000000        1952.0           311646.540984
# 875      1614.0                 inf        1614.0            53237.293680
# 891       590.0            2.208333         590.0           165441.433898
# 894      3291.0            2.607143        3291.0            37518.419933
# 924      3881.0            8.555556        3881.0            63820.954136
# 930       678.0            5.000000         678.0           276846.000000
#
# [29 rows x 28 columns]

# %% [markdown]
# ## Zadanie 16.
#
# **Sprawdź, czy bardziej energetyczne utwory mają też większy `liveness_%`.** (Porównaj średnie wartości.)
#
# **Rozwiązanie:**

# %%
energy_avg = df['energy_%'].mean()
liveness_avg = df['liveness_%'].mean()

print("Energy avg", energy_avg)
print("Liveness avg", liveness_avg)

print("More energetic avg liveness", df.query('`energy_%` > @energy_avg')['liveness_%'].mean())
print("More lively avg energy", df.query('`liveness_%` > @liveness_avg')['energy_%'].mean())
# Out:
# Energy avg 64.2791185729276
# Liveness avg 18.213011542497377
# More energetic avg liveness 19.262425447316105
# More lively avg energy 66.95333333333333

# %% [markdown]
# ## Zadanie 17.
#
# **Znajdź wszystkie utwory, które mają `streams` powyżej średniej, ale są w mniej niż 100 playlistach Spotify.**
#
# **Rozwiązanie:**

# %%
avg_streams = df['streams'].mean()
print(df.query("`streams` > @avg_streams and `in_spotify_playlists` < 100"))
df.query("`in_spotify_playlists` < 100")
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts, in_deezer_playlists, in_deezer_charts, in_shazam_charts, bpm, key, mode, danceability_%, valence_%, energy_%, acousticness_%, instrumentalness_%, liveness_%, speechiness_%, in_playlist, energy_to_acoustic, playlist_sum, stream_to_playlist_sum]
# Index: []
#
# [0 rows x 28 columns]
#                                      track_name              artist(s)_name  \
# 94                               Still With You                   Jung Kook
# 104                                   New Jeans                    NewJeans
# 112                                     LAGUNAS   Jasiel Nuï¿½ï¿½ez, Peso P
# 113                     Mine (Taylor's Version)                Taylor Swift
# 150                              Mi Bello Angel               Natanael Cano
# 185                                     Cheques                       Shubh
# 193      Better Than Revenge (Taylor's Version)                Taylor Swift
# 327  Peaches (from The Super Mario Bros. Movie)                  Jack Black
# 344               Apna Bana Le (From "Bhediya")  Arijit Singh, Sachin-Jigar
#
#      artist_count  released_year  released_month  released_day  \
# 94              1           2020               6             5
# 104             1           2023               7             7
# 112             2           2023               6            22
# 113             1           2023               7             7
# 150             1           2023               6            30
# 185             1           2023               5            19
# 193             1           2023               7             7
# 327             1           2023               4             7
# 344             2           2022              11             5
#
#      in_spotify_playlists  in_spotify_charts      streams  in_apple_playlists  \
# 94                     31                 39   38411956.0                   2
# 104                    77                 35   29562220.0                   8
# 112                    58                 18   39058561.0                   2
# 113                    99                 15   36912123.0                  21
# 150                    86                  8   31873544.0                   7
# 185                    67                  8   47956378.0                   7
# 193                    86                 11   30343206.0                   3
# 327                    34                  0   68216992.0                   0
# 344                    86                  0  139836056.0                  11
#
#      ...  valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# 94   ...         34        47               9                   0          83
# 104  ...         53        72              51                   0          12
# 112  ...         79        62              33                   1          15
# 113  ...         49        78               0                   0          17
# 150  ...         90        77               1                   0           9
# 185  ...         36        63              26                   0          27
# 193  ...         67        89               0                   0          19
# 327  ...         41        31              79                   0          10
# 344  ...         44        56              80                   0           6
#
#     speechiness_% in_playlist  energy_to_acoustic  playlist_sum  \
# 94              4        41.0            5.222222          41.0
# 104             5        89.0            1.411765          89.0
# 112             3        64.0            1.878788          64.0
# 113             4       126.0                 inf         126.0
# 150             5        96.0           77.000000          96.0
# 185             5        74.0            2.423077          74.0
# 193             8        92.0                 inf          92.0
# 327             5        34.0            0.392405          34.0
# 344             3        97.0            0.700000          97.0
#
#      stream_to_playlist_sum
# 94             9.368770e+05
# 104            3.321598e+05
# 112            6.102900e+05
# 113            2.929534e+05
# 150            3.320161e+05
# 185            6.480592e+05
# 193            3.298175e+05
# 327            2.006382e+06
# 344            1.441609e+06
#
# [9 rows x 28 columns]

# %% [markdown]
# ## Zadanie 18.
#
# **Które utwory są najbardziej „zbalansowane”? Tzn. mają `danceability_%`, `energy_%` i `valence_%` zbliżone do średnich (różnice < 10).** Porównaj do średnich za pomocą `abs()`.
#
# **Rozwiązanie:**

# %%
avg_df = df[['danceability_%', 'energy_%', 'valence_%']].mean()
print(avg_df)
close_to_avg = abs(df[['danceability_%', 'energy_%', 'valence_%']] - avg_df) < 10
df[close_to_avg['danceability_%'] & close_to_avg['energy_%'] & close_to_avg['valence_%']]
# Out:
# danceability_%    66.969570
# energy_%          64.279119
# valence_%         51.431270
# dtype: float64
#                                 track_name  \
# 1                                     LALA
# 10                               un x100to
# 15                               Kill Bill
# 33                               Anti-Hero
# 34                                     TQG
# ..                                     ...
# 855                 Crazy What Love Can Do
# 885           Si Te La Encuentras Por Ahï¿
# 906                             Ferxxo 100
# 932  Pussy & Millions (feat. Travis Scott)
# 947                          The Great War
#
#                                artist(s)_name  artist_count  released_year  \
# 1                                 Myke Towers             1           2023
# 10                  Bad Bunny, Grupo Frontera             2           2023
# 15                                        SZA             1           2022
# 33                               Taylor Swift             1           2022
# 34                           Karol G, Shakira             2           2023
# ..                                        ...           ...            ...
# 855  David Guetta, Ella Henderson, Becky Hill             3           2022
# 885                                      Feid             1           2022
# 906                                      Feid             1           2022
# 932            Drake, Travis Scott, 21 Savage             3           2022
# 947                              Taylor Swift             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 1                 3            23                  1474                 48
# 10                4            17                  2876                 40
# 15               12             8                  8109                 77
# 33               10            21                  9082                 56
# 34                2            23                  4284                 49
# ..              ...           ...                   ...                ...
# 855               3            18                  5290                  0
# 885               8             5                  1379                  4
# 906               6             3                  1647                 30
# 932              11             4                  1930                  0
# 947              10            21                  1274                  0
#
#           streams  in_apple_playlists  ...  valence_%  energy_%  \
# 1    1.337163e+08                  48  ...         61        74
# 10   5.056714e+08                  41  ...         56        72
# 15   1.163094e+09                 183  ...         43        73
# 33   9.997483e+08                 242  ...         51        63
# 34   6.189904e+08                 115  ...         61        63
# ..            ...                 ...  ...        ...       ...
# 855  2.867395e+08                 139  ...         46        71
# 885  1.790614e+08                  23  ...         46        58
# 906  2.789200e+08                  20  ...         58        57
# 932  1.913337e+08                  24  ...         45        63
# 947  1.813826e+08                   1  ...         55        74
#
#      acousticness_%  instrumentalness_%  liveness_% speechiness_% in_playlist  \
# 1                 7                   0          10             4      1580.0
# 10               23                   0          27             5      2971.0
# 15                5                  17          16             4      8453.0
# 33               12                   0          19             5      9489.0
# 34               67                   0           9            28      4583.0
# ..              ...                 ...         ...           ...         ...
# 855               3                   0          16             4      5571.0
# 885              15                   0          13             8      1420.0
# 906              25                   0          15             7      1690.0
# 932               6                   0          35            12      1971.0
# 947              22                   0           8             4      1286.0
#
#      energy_to_acoustic  playlist_sum  stream_to_playlist_sum
# 1             10.571429        1580.0            84630.560759
# 10             3.130435        2971.0           170202.436217
# 15            14.600000        8453.0           137595.368981
# 33             5.250000        9489.0           105358.654969
# 34             0.940299        4583.0           135062.272093
# ..                  ...           ...                     ...
# 855           23.666667        5571.0            51470.019027
# 885            3.866667        1420.0           126099.605634
# 906            2.280000        1690.0           165041.424260
# 932           10.500000        1971.0            97074.406900
# 947            3.363636        1286.0           141044.004666
#
# [65 rows x 28 columns]

# %% [markdown]
# ## Zadanie 19.
#
# **Oblicz całkowitą liczbę artystów w bazie (`artist_count`).**
#
# **Rozwiązanie:**

# %%
print(df['artist_count'].sum())

import numpy as np
len([e for t in df['artist(s)_name'].unique() for e in t.split(', ')])
# Out:
# 1483
# 1149

# %% [markdown]
# ## Zadanie 20.
#
# **Zbadaj zależność między tanecznością a mówionością (`speechiness_%`) — czy bardziej taneczne utwory są mniej „gadane”?**
#
# **Rozwiązanie:**

# %%
df[['danceability_%', 'speechiness_%']].corr()
# Out:
#                 danceability_%  speechiness_%
# danceability_%        1.000000       0.184977
# speechiness_%         0.184977       1.000000

# %% [markdown]
# tak
